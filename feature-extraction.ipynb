# %%
import caffe

# %%
# %matplotlib inline
# %run feature_extraction
# Out:
# 237152
# ('working on ', '0')
# Predicted class is #927.
# ('working on ', '50')
# Predicted class is #965.
# ('working on ', '100')
# Predicted class is #809.
# ('working on ', '150')
# Predicted class is #923.
# ('working on ', '200')
# Predicted class is #766.
# ('working on ', '250')
# Predicted class is #923.
# ('working on ', '300')
# Predicted class is #440.
# ('working on ', '350')
# Predicted class is #926.
# ('working on ', '400')
# Predicted class is #923.
# ('working on ', '450')
# Predicted class is #923.
# ('working on ', '500')
# Predicted class is #935.
# ('working on ', '550')
# Predicted class is #925.
# ('working on ', '600')
# Predicted class is #962.
# ('working on ', '650')
# Predicted class is #36.
# ('working on ', '700')
# Predicted class is #960.
# ('working on ', '750')
# Predicted class is #923.
# ('working on ', '800')
# Predicted class is #935.
# ('working on ', '850')
# Predicted class is #56.
# ('working on ', '900')
# Predicted class is #762.
# ...
